# %%
import sys
from pathlib import Path

PROJ_ROOT = "../../"
INPUT_FILE_PATH = PROJ_ROOT + "input"
sys.path.insert(0, PROJ_ROOT)

# %%
import pandas as pd
from src.preprocess.read_file import read_file

# %%
train_df = pd.read_csv(f"{INPUT_FILE_PATH}/train.csv")
test_df = pd.read_csv(f"{INPUT_FILE_PATH}/test.csv")

# %%
train_df
# Out:
#           id      賃料                所在地  \
# 0          1   75000        東京都北区滝野川３丁目
# 1          2   76000        東京都中央区月島３丁目
# 2          3  110000        東京都渋谷区笹塚２丁目
# 3          4  150000  東京都杉並区高円寺南２丁目23-2
# 4          5   74000     東京都葛飾区金町３丁目7-2
# ...      ...     ...                ...
# 31465  31466   80000        東京都板橋区蓮根２丁目
# 31466  31467   54500  東京都世田谷区太子堂５丁目17-1
# 31467  31468  125000        東京都江東区南砂４丁目
# 31468  31469   98000        東京都中野区中野２丁目
# 31469  31470   81000        東京都豊島区千川２丁目
#
#                                                     アクセス   間取り      築年数   方角  \
# 0      都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...    1K    9年9ヶ月   南東
# 1      都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...    1R  44年10ヶ月  NaN
# 2      京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...    1K    8年6ヶ月    南
# 3      総武線・中央線（各停）\t高円寺駅\t徒歩9分\t\t丸ノ内線(池袋－荻窪)\t新高円寺駅\...  2LDK   29年4ヶ月    南
# 4      京成金町線\t京成金町駅\t徒歩5分\t\t常磐線\t金町(東京都)駅\t徒歩7分\t\t京...   2DK   31年7ヶ月    南
# ...

# %%
test_df
# Out:
#           id                所在地  \
# 0      31471   東京都世田谷区深沢５丁目1-27
# 1      31472    東京都目黒区八雲１丁目11-8
# 2      31473  東京都豊島区池袋本町２丁目22-2
# 3      31474        東京都杉並区和泉１丁目
# 4      31475       東京都杉並区堀ノ内２丁目
# ...      ...                ...
# 31257  62728       東京都豊島区上池袋４丁目
# 31258  62729      東京都千代田区岩本町２丁目
# 31259  62730   東京都中野区江古田３丁目14-3
# 31260  62731         東京都千代田区二番町
# 31261  62732       東京都大田区南馬込６丁目
#
#                                                     アクセス   間取り     築年数  方角  \
# 0      東急大井町線\t等々力駅\t徒歩15分\t\t東急田園都市線\t桜新町駅\t徒歩24分\t\...  2LDK  49年0ヶ月   南
# 1      東急東横線\t都立大学駅\t徒歩6分\t\t東急東横線\t自由が丘駅\t徒歩17分\t\t東...    1R   0年2ヶ月  南東
# 2      東武東上線\t北池袋駅\t徒歩10分\t\t埼京線\t板橋駅\t徒歩16分\t\t山手線\t...    1K  23年4ヶ月  南東
# 3      丸ノ内線(中野坂上－方南町)\t方南町駅\t徒歩10分\t\t京王線\t代田橋駅\t徒歩8分...    1K  36年2ヶ月  南東
# 4      丸ノ内線(中野坂上－方南町)\t方南町駅\t徒歩12分\t\t丸ノ内線(池袋－荻窪)\t新高...  2LDK  45年4ヶ月   南
# ...                                                  ...   ...     ...  ..
# ...

# %%
df = read_file(INPUT_FILE_PATH)

# %%
df
# Out:
#                                                   access            address  \
# 0      都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...        東京都北区滝野川３丁目
# 1      都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...        東京都中央区月島３丁目
# 2      京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...        東京都渋谷区笹塚２丁目
# 3      総武線・中央線（各停）\t高円寺駅\t徒歩9分\t\t丸ノ内線(池袋－荻窪)\t新高円寺駅\...  東京都杉並区高円寺南２丁目23-2
# 4      京成金町線\t京成金町駅\t徒歩5分\t\t常磐線\t金町(東京都)駅\t徒歩7分\t\t京...     東京都葛飾区金町３丁目7-2
# ...                                                  ...                ...
# 31257  埼京線\t板橋駅\t徒歩3分\t\t都営三田線\t新板橋駅\t徒歩9分\t\t東武東上線\t...       東京都豊島区上池袋４丁目
# 31258  都営新宿線\t岩本町駅\t徒歩2分\t\t山手線\t秋葉原駅\t徒歩4分\t\t日比谷線\t...      東京都千代田区岩本町２丁目
# 31259  都営大江戸線\t新江古田駅\t徒歩10分\t\t西武池袋線\t江古田駅\t徒歩20分\t\t...   東京都中野区江古田３丁目14-3
# 31260  有楽町線\t麹町駅\t徒歩3分\t\t丸ノ内線(池袋－荻窪)\t四ツ谷駅\t徒歩4分\t\t...         東京都千代田区二番町
# 31261  都営浅草線\t西馬込駅\t徒歩8分\t\t東急池上線\t池上駅\t徒歩19分\t\t都営浅草...       東京都大田区南馬込６丁目
#
# ...
